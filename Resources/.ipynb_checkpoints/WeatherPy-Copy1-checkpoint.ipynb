# %% [markdown]
# # WeatherPy to Table
# ----

# %%
import pandas as pd

# %%
df = pd.read_csv('WeatherPy.csv')
df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Te Anau          95      NZ  1564447514        96 -45.41  167.72
# 1     Rikitea         100      PF  1564447514        76 -23.12 -134.97
# 2  Bredasdorp          35      ZA  1564447514        76 -34.53   20.04
# 3      Avarua           0      CK  1564447514        78 -21.21 -159.78
# 4      Surgut           0      RU  1564447515        77  61.25   73.40
#
#    Max Temp  Wind Speed
# 0     38.75        3.33
# 1     69.71       20.92
# 2     57.20        9.17
# 3     78.80       16.11
# 4     66.20       13.42

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Te Anau</td>\n      <td>95</td>\n      <td>NZ</td>\n      <td>1564447514</td>\n      <td>96</td>\n      <td>-45.41</td>\n      <td>167.72</td>\n      <td>38.75</td>\n      <td>3.33</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Rikitea</td>\n      <td>100</td>\n      <td>PF</td>\n      <td>1564447514</td>\n      <td>76</td>\n      <td>-23.12</td>\n      <td>-134.97</td>\n      <td>69.71</td>\n      <td>20.92</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Bredasdorp</td>\n      <td>35</td>\n      <td>ZA</td>\n      <td>1564447514</td>\n      <td>76</td>\n      <td>-34.53</td>\n      <td>20.
# ...

# %%
df.to_html('table.html')
